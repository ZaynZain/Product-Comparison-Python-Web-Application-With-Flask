# %%
import mysql.connector
import csv

# Create a database connection object and configure it here
connection = mysql.connector.connect(
    host="localhost",
    user="root",
    password="",
    database="csvdatastore"
)

def insert_data_to_database(connection, data1):
    try:
        cursor = connection.cursor()
        for row in data1:
            insert_query1 = "INSERT INTO laptops (`laptops-href`, `productname`, `price`, `discount`, `detai_lproduct`, `photo-src`) VALUES (%s, %s, %s, %s, %s, %s)"
            cursor.execute(insert_query1, (row['laptops-href'], row['productname'], row['price'], row['discount'], row['detai_lproduct'], row['photo-src']))
            print("data added")


        connection.commit()
        cursor.close()
    except Exception as e:
        print(f"An error occurred while inserting data: {str(e)}")

def read_csv_file(file_path):
    data = []
    with open(file_path, 'r', newline='') as csvfile:
        reader = csv.DictReader(csvfile)
        for row in reader:
            data.append(row)
    return data

def main():
    file_path1 = 'amzon_Laptops.csv'  # Replace with the path to your CSV file
    data1 = read_csv_file(file_path1)

   

    insert_data_to_database(connection, data1)  # Pass the connection object and data2

if __name__ == "__main__":
    main()
# Out:
# data added
# data added
# data added
# data added
# data added
# data added
# data added
# data added
# data added
# data added
# data added
# data added

# %%
import mysql.connector
import csv

# Create a database connection object and configure it here
connection = mysql.connector.connect(
    host="localhost",
    user="root",
    password="",
    database="csvdatastore"
)

def insert_data_to_database(connection, data1):
    try:
        cursor = connection.cursor()
        for row in data1:
            insert_query1 = "INSERT INTO daraz_laptops (`laptop-href`, `title`, `price`, `description`, `photo_url`, `rating`) VALUES (%s, %s, %s, %s, %s, %s)"
            cursor.execute(insert_query1, (row['laptop-href'], row['title'], row['price'], row['description'], row['photo_url'], row['rating']))
            print("data added")


        connection.commit()
        cursor.close()
    except Exception as e:
        print(f"An error occurred while inserting data: {str(e)}")

def read_csv_file(file_path):
    data = []
    with open(file_path, 'r', newline='') as csvfile:
        reader = csv.DictReader(csvfile)
        for row in reader:
            data.append(row)
    return data

def main():
    file_path2 = 'daraz_laptops.csv'  # Replace with the path to your CSV file
    data1 = read_csv_file(file_path2)

   

    insert_data_to_database(connection, data1)  # Pass the connection object and data2

if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# Cell In[19], line 43
#      40     insert_data_to_database(connection, data1)  # Pass the connection object and data2
#      42 if __name__ == "__main__":
# ---> 43     main()
#
# Cell In[19], line 36, in main()
#      34 def main():
#      35     file_path2 = 'daraz_laptops.csv'  # Replace with the path to your CSV file
# ---> 36     data1 = read_csv_file(file_path2)
#      40     insert_data_to_database(connection, data1)
#
# Cell In[19], line 30, in read_csv_file(file_path)
#      28 with open(file_path, 'r', newline='') as csvfile:
#      29     reader = csv.DictReader(csvfile)
# ---> 30     for row in reader:
#      31         data.append(row)
#      32 return data
#
# File ~\AppData\Local\Programs\Python\Python39\lib\csv.py:110, in DictReader.__next__(self)
#     107 def __next__(self):
#     108     if self.line_num == 0:
#     109         # Used only for its side effect.
# --> 110         self.fieldnames
#     111     row = next(self.reader)
#     112     self.line_num = self.reader.line_num
#
# File ~\AppData\Local\Programs\Python\Python39\lib\csv.py:97, in DictReader.fieldnames(self)
#      95 if self._fieldnames is None:
#      96     try:
# ---> 97         self._fieldnames = next(self.reader)
#      98     except StopIteration:
#      99         pass
#
# Error: line contains NUL

# %%
import mysql.connector
import csv

# Create a database connection object and configure it here
connection = mysql.connector.connect(
    host="localhost",
    user="root",
    password="",
    database="csvdatastore"
)

def insert_data_to_database(connection, data1):
    try:
        cursor = connection.cursor()
        for row in data1:
            
            insert_query1 = "INSERT INTO daraz_laptops (`laptop-href`, `title`, `price`, `description`, `photo_url-src`, `rating`) VALUES (%s, %s, %s, %s, %s, %s)"
            cursor.execute(insert_query1, (row['laptop-href'], row['title'], row['price'], row['description'], row['photo_url-src'], row['rating']))
            print("data added")


        connection.commit()
        cursor.close()
    except Exception as e:
        print(f"An error occurred while inserting data: {str(e)}")

def read_csv_file(file_path):
    data = []
    with open(file_path, 'r', newline='') as csvfile:
        reader = csv.DictReader(csvfile)
        for row in reader:
            data.append(row)
    return data

def main():
    file_path2 = 'daraz_laptops.csv'  # Replace with the path to your CSV file
    data1 = read_csv_file(file_path2)

   

    insert_data_to_database(connection, data1)  # Pass the connection object and data2

if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# Cell In[18], line 44
#      41     insert_data_to_database(connection, data1)  # Pass the connection object and data2
#      43 if __name__ == "__main__":
# ---> 44     main()
#
# Cell In[18], line 37, in main()
#      35 def main():
#      36     file_path2 = 'daraz_laptops.csv'  # Replace with the path to your CSV file
# ---> 37     data1 = read_csv_file(file_path2)
#      41     insert_data_to_database(connection, data1)
#
# Cell In[18], line 31, in read_csv_file(file_path)
#      29 with open(file_path, 'r', newline='') as csvfile:
#      30     reader = csv.DictReader(csvfile)
# ---> 31     for row in reader:
#      32         data.append(row)
#      33 return data
#
# File ~\AppData\Local\Programs\Python\Python39\lib\csv.py:110, in DictReader.__next__(self)
#     107 def __next__(self):
#     108     if self.line_num == 0:
#     109         # Used only for its side effect.
# --> 110         self.fieldnames
#     111     row = next(self.reader)
#     112     self.line_num = self.reader.line_num
#
# File ~\AppData\Local\Programs\Python\Python39\lib\csv.py:97, in DictReader.fieldnames(self)
#      95 if self._fieldnames is None:
#      96     try:
# ---> 97         self._fieldnames = next(self.reader)
#      98     except StopIteration:
#      99         pass
#
# Error: line contains NUL
